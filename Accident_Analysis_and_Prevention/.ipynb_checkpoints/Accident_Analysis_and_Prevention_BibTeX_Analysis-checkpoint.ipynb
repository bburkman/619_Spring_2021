# %% [markdown]
# # Setup

# %% [markdown]
# ## Import Libraries

# %%
import bibtexparser
import pandas as pd
import numpy as np

# %% [markdown]
# ## Parse .bib File

# %%
with open('Accident_Analysis_and_Prevention.bib') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

# %% [markdown]
# ## Create Pandas Dataframe

# %%
P = pd.DataFrame(bib_database.entries)
P
# Out:
#                                             annotation  \
# 0                                           Stuff Here
# 1                                                  NaN
# 2    Highway-Rail Grade Crossing, found two correla...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
# 332                                                NaN
#
#                                               abstract  \
# 0    Purpose\nSafety climate, which is defined as w...
# 1    Hotspot identification (HSID) is one of the mo...
# 2    This paper proposes a machine learning approac...
# 3    Current automated driving technology cannot co...
# 4    Although the fatal rate of passenger vehicle-i...
# ..                                                 ...
# 328  This paper, presented in two parts, assesses t...
# 329  The present study examines workers' responses ...
# 330  The problem of road casualties in the United S...
# 331                                                NaN
# 332  Nigerian Coal Corporation started operations i...
#
#                                               keywords  \
# 0    Safety climate, Bayesian network analysis, Lea...
# 1    Network screening, Hotspot identification meth...
# 2    Accident prediction, Railroad grade crossing, ...
# 3    Automated driving, expert driver, prospective ...
# 4    Severity analysis, Truck crashes, Intersection...
# ..                                                 ...
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
# 332                                                NaN
#
#                                                 author  \
# 0    Yueng-hsiang Huang and Yimin He and Jin Lee an...
# 1         Xiaoyu Guo and Lingtao Wu and Dominique Lord
# 2    Amin Keramati and Pan Lu and Amirfarrokh Irani...
# 3    Hilkka Grahn and Tuomo Kujala and Johanna Silv...
# 4                                  Li Song and Wei Fan
# ..                                                 ...
# 328                                      Urban Kjellén
# 329                                     Toivo Niskanen
# 330                              Anthony N. Kontaratos
# 331                                                NaN
# 332                                        S.E. Asogwa
#
#                                                    url  \
# 0    https://www.sciencedirect.com/science/article/...
# 1    https://www.sciencedirect.com/science/article/...
# 2    https://www.sciencedirect.com/science/article/...
# 3    https://www.sciencedirect.com/science/article/...
# 4    https://www.sciencedirect.com/science/article/...
# ..                                                 ...
# 328  https://www.sciencedirect.com/science/article/...
# 329  https://www.sciencedirect.com/science/article/...
# 330  https://www.sciencedirect.com/science/article/...
# 331  https://www.sciencedirect.com/science/article/...
# 332  https://www.sciencedirect.com/science/article/...
#
#                                               doi       issn  year    pages  \
# 0       https://doi.org/10.1016/j.aap.2020.105850  0001-4575  2021   105850
# 1       https://doi.org/10.1016/j.aap.2020.105684  0001-4575  2020   105684
# 2       https://doi.org/10.1016/j.aap.2020.105683  0001-4575  2020   105683
# 3       https://doi.org/10.1016/j.aap.2020.105717  0001-4575  2020   105717
# 4       https://doi.org/10.1016/j.aap.2020.105638  0001-4575  2020   105638
# ..                                            ...        ...   ...      ...
# 328  https://doi.org/10.1016/0001-4575(84)90023-X  0001-4575  1984  289-306
# 329  https://doi.org/10.1016/0001-4575(94)90066-3  0001-4575  1994    27-39
# 330  https://doi.org/10.1016/0001-4575(74)90002-5  0001-4575  1974  223-241
# 331  https://doi.org/10.1016/0001-4575(75)90009-3  0001-4575  1975  155-158
# 332  https://doi.org/10.1016/0001-4575(88)90025-5  0001-4575  1988  103-108
#
#     volume                          journal  \
# 0      150  Accident Analysis \& Prevention
# 1      145  Accident Analysis \& Prevention
# 2      144  Accident Analysis \& Prevention
# 3      146  Accident Analysis \& Prevention
# 4      144  Accident Analysis \& Prevention
# ..     ...                              ...
# 328     16  Accident Analysis \& Prevention
# 329     26  Accident Analysis \& Prevention
# 330      6  Accident Analysis \& Prevention
# 331      7  Accident Analysis \& Prevention
# 332     20  Accident Analysis \& Prevention
#
#                                                  title ENTRYTYPE  \
# 0    Key drivers of trucking safety climate from th...   article
# 1    Generalized criteria for evaluating hotspot id...   article
# 2    A crash severity analysis at highway-rail grad...   article
# 3    Expert Drivers’ Prospective Thinking-Aloud to ...   article
# 4    Combined latent class and partial proportional...   article
# ..                                                 ...       ...
# 328  The deviation concept in occupational accident...   article
# 329  Assessing the safety environment in work organ...   article
# 330  A systems analysis of the problem of road casu...   article
# 331                                Recent publications   article
# 332  The health benefits of mechanization at the Ni...   article
#
#                      ID addendum           institution note number
# 0       HUANG2021105850      NaN                   NaN  NaN    NaN
# 1         GUO2020105684      NaN                   NaN  NaN    NaN
# 2    KERAMATI2020105683     None  North Dakota State U  NaN    NaN
# 3       GRAHN2020105717      NaN                   NaN  NaN    NaN
# 4        SONG2020105638      NaN                   NaN  NaN    NaN
# ..                  ...      ...                   ...  ...    ...
# 328      KJELLEN1984289      NaN                   NaN  NaN      4
# 329      NISKANEN199427      NaN                   NaN  NaN      1
# 330   KONTARATOS1974223      NaN                   NaN  NaN      3
# 331             1975155      NaN                   NaN  NaN      2
# 332       ASOGWA1988103      NaN                   NaN  NaN      2
#
# [333 rows x 18 columns]

# %% [markdown]
# # Fields in .bib File

# %%
for row in P:
    print (row)
# Out:
# annotation
# abstract
# keywords
# author
# url
# doi
# issn
# year
# pages
# volume
# journal
# title
# ENTRYTYPE
# ID
# addendum
# institution
# note
# number

# %% [markdown]
# # Keywords
# ## Sort Keywords by Frequency

# %%
P['keywords'] = P['keywords'].fillna('None')
A = [ x.split(', ') for x in P['keywords'].tolist() ]
B = [item for sublist in A for item in sublist]
C = {x:B.count(x) for x in B}
D = dict(sorted(C.items(), key=lambda item: item[1], reverse=True))
D
# Out:
# {'None': 39,
#  'Machine learning': 32,
#  'Road safety': 14,
#  'Safety': 13,
#  'Traffic safety': 9,
#  'Deep learning': 9,
#  'Automated driving': 7,
#  'Crash severity': 7,
#  'Data mining': 7,
#  'Support vector machine': 7,
#  'Connected vehicles': 6,
#  'Driving simulator': 6,
#  'Fatigue': 6,
#  'Driver behavior': 6,
#  'Classification': 5,
#  'Injury severity': 5,
#  'Crash prediction': 5,
#  'Drowsiness': 5,
#  'Naturalistic driving': 5,
#  'Accident analysis': 5,
#  'Negative binomial model': 5,
#  'Naturalistic driving study': 5,
#  'Random forest': 5,
#  'Motorcycle': 5,
#  'Ergonomics': 5,
#  'Driver distraction': 5,
#  'Driving behavior': 4,
#  'Text mining': 4,
#  'Distracted driving': 4,
#  'Built environment': 4,
#  'Sleep': 4,
#  'Traffic conflicts': 4,
#  'Neural network': 4,
#  'Risk perception': 4,
#  'Driver behaviour': 4,
#  'Crash': 4,
#  'Risk': 4,
#  'Accident causation': 4,
#  'Police records': 4,
#  'Narrative text': 4,
#  'Driving': 3,
#  'Naturalistic driving data': 3,
#  'Spatial analysis': 3,
#  'Machine Learning': 3,
#  'Decision tree': 3,
#  'Car-following': 3,
#  'Driving performance': 3,
#  'LSTM': 3,
#  'SHRP2': 3,
#  'Older drivers': 3,
#  'Bayesian networks': 3,
#  'Transition of control': 3,
#  'Driving simulator experiment': 3,
#  'Random Forest': 3,
#  'Artificial neural network': 3,
#  'Transportation safety': 3,
#  'Prediction': 3,
#  'Imbalanced data': 3,
#  'Young drivers': 3,
#  'Bayesian network': 3,
#  'Crash risk prediction': 3,
#  'Training': 3,
#  'Traffic accidents': 3,
#  'Distraction': 3,
#  'Driver performance': 3,
#  'Attitudes': 3,
#  'Aging': 3,
#  'Injury surveillance': 3,
#  'Road junction': 3,
#  'Injury': 3,
#  'Support vector machine model': 3,
#  'Safety climate': 2,
#  'Latent class clustering': 2,
#  'Smartphone data': 2,
#  'Driving under the influence': 2,
#  'Traffic simulation': 2,
#  'Big Data': 2,
#  'Intelligent transportation systems': 2,
#  'Electroencephalography (EEG)': 2,
#  'Deep Learning': 2,
#  'Advanced Driver Assistance Systems': 2,
#  'Surrogate measures of safety': 2,
#  'Lane-changing': 2,
#  'Predictive models': 2,
#  'Ordered probit model': 2,
#  'Secondary tasks': 2,
#  'Association rules': 2,
#  'Driver state': 2,
#  'Trust': 2,
#  'Structural equation modeling': 2,
#  'Surrogate safety measures': 2,
#  'Mental workload': 2,
#  'Driver assistance system': 2,
#  'Vehicle trajectory data': 2,
#  'Vehicle crashes': 2,
#  'Anticipation': 2,
#  'Urban arterials': 2,
#  'Work zone': 2,
#  'Freeway safety': 2,
#  'Safety critical events': 2,
#  'Bibliometrics': 2,
#  'Feature learning': 2,
#  'Highly automated driving': 2,
#  'Signalized intersection': 2,
#  'Crash injury severity': 2,
#  'Bayesian additive regression trees': 2,
#  'Human–automation interaction': 2,
#  'MARS': 2,
#  'Autonomous vehicles': 2,
#  'Variable speed limit': 2,
#  'Sensation seeking': 2,
#  'Structural equation model': 2,
#  'Pedestrian safety': 2,
#  'Fuzzy logic': 2,
#  'Safety effectiveness': 2,
#  'Real-time data': 2,
#  'Predictive modeling': 2,
#  'Connected vehicle': 2,
#  'Naïve Bayes': 2,
#  'Classification and regression tree': 2,
#  'Electroencephalogram (EEG)': 2,
#  'Transferability': 2,
#  'Support vector machines': 2,
#  'Random forests': 2,
#  'Reliability': 2,
#  'Genetic algorithm': 2,
#  'Detection': 2,
#  'Computer vision': 2,
#  'Logistic regression': 2,
#  'Mixed logit model': 2,
#  'Head-up display (HUD) visualization': 2,
#  'Freeway': 2,
#  'Back-propagation neural network': 2,
#  'Binary classification': 2,
#  'Crash risk': 2,
#  'Crash likelihood': 2,
#  'Real-time crash risk': 2,
#  'Variable importance': 2,
#  'Controllability': 2,
#  'Trajectory data': 2,
#  'Drowsy driving': 2,
#  'Driving behaviour': 2,
#  'XGBoost': 2,
#  'Highway': 2,
#  'Hazard-based duration model': 2,
#  'Run-off-road crash': 2,
#  'Crash detection': 2,
#  'Construction safety': 2,
#  'Bayesian inference': 2,
#  'Traffic flow': 2,
#  'Collision risk': 2,
#  'Clustering': 2,
#  'Collision avoidance': 2,
#  'Accident detection': 2,
#  'Urban expressway': 2,
#  'Near-crash': 2,
#  'Human factors': 2,
#  'Crash mechanism': 2,
#  'Adaptive systems': 2,
#  'System safety': 2,
#  'Human error': 2,
#  'Speeding': 2,
#  'Motorcycling': 2,
#  'Accident': 2,
#  'Safety management': 2,
#  'Multivariate adaptive regression splines': 2,
#  'Workload': 2,
#  'Genetic programming': 2,
#  'Dilemma zone': 2,
#  'Driver injury severity': 2,
#  'Red-light running': 2,
#  'Simulation': 2,
#  'Novice': 2,
#  'Systems theory': 2,
#  'Bayesian network analysis': 1,
#  'Leader-member exchange': 1,
#  'Network screening': 1,
#  'Hotspot identification method': 1,
#  'Performance evaluation': 1,
#  'Multiple periods': 1,
#  'Accident prediction': 1,
#  'Railroad grade crossing': 1,
#  'Random survival forests': 1,
#  'expert driver': 1,
#  'prospective thinking-aloud': 1,
#  'traffic safety': 1,
#  'uncertainty': 1,
#  'anticipation': 1,
#  'Severity analysis': 1,
#  'Truck crashes': 1,
#  'Intersection': 1,
#  'Partial proportional odds model': 1,
#  'Driving safety efficiency': 1,
#  'Temporal evolution': 1,
#  'K-means clustering': 1,
#  'Automobile driving': 1,
#  'Multiple fatal injury crash': 1,
#  'Model selection': 1,
#  'Class imbalance': 1,
#  'Oversampling': 1,
#  'Ensemble classifiers': 1,
#  'Three-wheeled motorized rickshaws': 1,
#  'Machine learning (ML)': 1,
#  'Rawalpindi': 1,
#  'Vehicle platoon': 1,
#  'Interaction': 1,
#  'Crash type': 1,
#  'Severity': 1,
#  'GSEM': 1,
#  'Advanced vehicle technologies': 1,
#  'Advanced driver assistance systems': 1,
#  'Drivers': 1,
#  'Age': 1,
#  'Non-motorist trespassing crashes': 1,
#  'Non-crossings': 1,
#  'Text analysis': 1,
#  'Concept/Entity extraction': 1,
#  'Dynamic factor analysis': 1,
#  'Heterogeneity-based discrete outcome modeling': 1,
#  'Motor vehicle crashes': 1,
#  'Occupant protection': 1,
#  'Injury risk': 1,
#  'Prediction models': 1,
#  'Machine-learning algorithms': 1,
#  'Adaptive traffic signal control': 1,
#  'Real-time safety optimization': 1,
#  'Reinforcement learning': 1,
#  'Real-time safety models': 1,
#  'Connected and automated vehicles': 1,
#  'Driving risk status prediction': 1,
#  'Rolling time window approach': 1,
#  'Car-following events': 1,
#  'Machine learning algorithms': 1,
#  'Intelligent connected vehicle': 1,
#  'Driver modeling': 1,
#  'Risk field theory': 1,
#  'Car-following tasks': 1,
#  'Human driving strategy': 1,
#  'Highway-rail grade crossing consolidation': 1,
#  'Crash severity safety': 1,
#  'Multiple states comparison': 1,
#  'crash cost': 1,
#  'quantile mixed model': 1,
#  'sparse data': 1,
#  'non-parametric modeling': 1,
#  'hierarchical model': 1,
#  'Driver brain activity': 1,
#  'Simulated driving': 1,
#  'Alcohol and cannabis': 1,
#  'Secondary task': 1,
#  'Driver decision-making': 1,
#  'Fatigue and drowsiness': 1,
#  'Neuroimaging': 1,
#  'Functional Magnetic Resonance Imaging (fMRI)': 1,
#  'Functional Near-Infrared Spectroscopy (fNIRS)': 1,
#  'Magnetoencephalography (MEG)': 1,
#  'Structural topic modeling': 1,
#  'Network topology': 1,
#  'Network centrality measures': 1,
#  'Traffic crashes': 1,
#  'Geographically and temporally weighted regression': 1,
#  'Spatio-temporal variation': 1,
#  'Foggy weather': 1,
#  'Image Classification': 1,
#  'TensorFlow': 1,
#  'Deep Neural Network': 1,
#  'Recurrent Neural Network': 1,
#  'Long Short-Term Memory': 1,
#  'Convolutional Neural Network': 1,
#  'Advanced Travel Information Systems': 1,
#  'Variable Speed Limit': 1,
#  'Mobile Weather Sensors': 1,
#  'Bicycle wrong way riding': 1,
#  'Bike sharing': 1,
#  'Multi-layer perceptron': 1,
#  'Convolutional neural network': 1,
#  'Crash-prone intersection': 1,
#  'Basic safety messages': 1,
#  'Connected environment': 1,
#  'Advanced driving simulator': 1,
#  'Velocity change ()': 1,
#  'Crash Momentum Index (CMI)': 1,
#  'A priori analysis': 1,
#  'Feature ranking': 1,
#  'Copula': 1,
#  'Temporal stability': 1,
#  'Expressway': 1,
#  'Bus-involved crashes': 1,
#  'Single-vehicle accident analysis': 1,
#  'Accident severity': 1,
#  'Severity prediction': 1,
#  'Non-parametric model': 1,
#  'Tree-based models': 1,
#  'Co-occurring behaviors': 1,
#  'Driving behaviors': 1,
#  'Midblock crossing': 1,
#  'Crossing speed': 1,
#  'Critical gap': 1,
#  'Image processing': 1,
#  'ROR crashes': 1,
#  'Severe and fatal crashes': 1,
#  'Safety countermeasures': 1,
#  'Driving capability assessment': 1,
#  'Longitudinal driving safety': 1,
#  'Responsibility-sensitive safety': 1,
#  'Bayesian Tobit quantile regression model': 1,
#  'At-fault crash driver': 1,
#  'Traffic violation': 1,
#  'Traffic enforcement': 1,
#  'Missing values': 1,
#  'Multiple imputation': 1,
#  'Mountainous roads': 1,
#  'Highway safety': 1,
#  'Socioeconomic factors': 1,
#  'Commercial motor vehicles': 1,
#  'Quasi-induced exposure technique': 1,
#  'Wyoming Connected Vehicle Pilot': 1,
#  'Microsimulation Modeling': 1,
#  'Adverse Weather': 1,
#  'Model Calibration': 1,
#  'Surrogate Measures of Safety (SMoS)': 1,
#  'Take-over performance': 1,
#  'Sleep inertia': 1,
#  'hazardous material': 1,
#  'association rules mining': 1,
#  'Apriori algorithm': 1,
#  'data mining': 1,
#  'expressways': 1,
#  'Level 3 automation': 1,
#  'Simulator experiment': 1,
#  'Takeover behavior variation': 1,
#  'Count data modelling': 1,
#  'Adaptive Signal control': 1,
#  'Multi-objective reinforcement learning': 1,
#  'Safety analysis': 1,
#  'Crash frequency': 1,
#  'Lomax distribution': 1,
#  'Road near-departures': 1,
#  'Connected and autonomous vehicles (CAVs)': 1,
#  'Electronic control units (ECUs)': 1,
#  'Cybersecurity': 1,
#  'CAVs communication framework': 1,
#  'Driverless cars': 1,
#  'Eco-Safe driving': 1,
#  'Visual demand': 1,
#  'Variational autoencoder': 1,
#  'Data augmentation': 1,
#  'Freeway operation and management': 1,
#  'High-crash risk': 1,
#  'Random-effects logistic regression model': 1,
#  'Traffic safety pre-warning': 1,
#  'Traffic campaigns': 1,
#  'Overconfidence': 1,
#  'Video': 1,
#  'Econometrics': 1,
#  'Regression model': 1,
#  'Energy absorption': 1,
#  'Rear-end collisions': 1,
#  'Cognitive psychology': 1,
#  'Cellular automaton model': 1,
#  'Conservative driver': 1,
#  'Aggressive driver': 1,
#  'Real-time crash potential prediction': 1,
#  'Connected vehicle emulated data': 1,
#  'Transportation': 1,
#  'Survival analysis': 1,
#  'Highway crashes': 1,
#  'Intrusion alert': 1,
#  'GANs': 1,
#  'Imbalance training samples': 1,
#  'Incident detection': 1,
#  'Spatial and temporal rules': 1,
#  'Surrogate safety framework': 1,
#  'Crash-conflict relationship': 1,
#  'Crash surrogates': 1,
#  'Surrogate based crash severity': 1,
#  'Segments with horizontal curvature': 1,
#  'Vehicle kinetic response': 1,
#  'Negative binomial regression model': 1,
#  'Random effects negative binomial regression model': 1,
#  'Features': 1,
#  'Ground truth': 1,
#  'Physiological sleepiness': 1,
#  'Driving volatility': 1,
#  'Bollinger bands': 1,
#  'Vehicle kinematics': 1,
#  'Mixed logit': 1,
#  'Driving instability': 1,
#  'Accident Analysis \\& Prevention': 1,
#  'Scientometrics': 1,
#  'Journal analysis': 1,
#  'Revised Haddon matrix': 1,
#  'Crash causal inference': 1,
#  'Copula-Bayesian Network': 1,
#  'Risky driving maneuver': 1,
#  'Pedestrian-vehicle conflicts': 1,
#  'Automatic incident detection': 1,
#  'Bluetooth sensors': 1,
#  'Takeover performance': 1,
#  'Left turns': 1,
#  'Harsh events': 1,
#  'Geometric characteristics': 1,
#  'Traffic characteristics': 1,
#  'Heavy vehicles': 1,
#  'Speed violation': 1,
#  'Imbalance data': 1,
#  'Oversampling techniques': 1,
#  'Data cleaning': 1,
#  'Feature engineering': 1,
#  'Financial loss': 1,
#  'Principle component analysis': 1,
#  'Risk management': 1,
#  'Continuous data environment': 1,
#  'Real-time crash risk prediction models': 1,
#  'Imbalanced data classification': 1,
#  'RCSMLP': 1,
#  'Rusboost model': 1,
#  'Traffic collision/accident severity': 1,
#  'Transfer learning': 1,
#  'Numeric to image transformation': 1,
#  'Customized loss function': 1,
#  'State-led suburbanization': 1,
#  'Neighborhood-level automobile-involved crash density': 1,
#  'Safe urban form': 1,
#  'Site ranking': 1,
#  'Spatial count data modelling': 1,
#  'Pólya-Gamma data augmentation': 1,
#  'Psychophysiological measures': 1,
#  'Bicycle-Vehicle Crashes': 1,
#  'Multivariate Adaptive Regression Splines': 1,
#  'Safety Performance Functions': 1,
#  'Conway-Maxwell-Poisson': 1,
#  'COM-Poisson': 1,
#  'Wyoming connected vehicle pilot': 1,
#  'Adverse weather': 1,
#  'Traveler information messages': 1,
#  'Speed harmonization': 1,
#  'Traffic accident prediction': 1,
#  'Neural networks': 1,
#  'Vehicle automation': 1,
#  'Gaze patterns': 1,
#  'Visual-motor coordination': 1,
#  'Lane change': 1,
#  'Driving strategy': 1,
#  'Risk appetite': 1,
#  'Interaction manner': 1,
#  'CNN': 1,
#  'Volatility': 1,
#  'Neural Network': 1,
#  'Traffic accident detection': 1,
#  'Traffic accident analysis': 1,
#  'Traffic monitoring system': 1,
#  'Ontology': 1,
#  'Bi-LSTM': 1,
#  'Active traffic management': 1,
#  'Bayesian modeling': 1,
#  'Lane control signals': 1,
#  'Driver driving risk': 1,
#  'Risky driving behaviors': 1,
#  'SHRP 2': 1,
#  'Surrogate safety measures (SSMs)': 1,
#  'Extreme value theory (EVT)': 1,
#  'Gated recurrent unit (GRU)': 1,
#  'Injury-severity': 1,
#  'Cyclist safety': 1,
#  'Driving automation systems': 1,
#  'Avoidance response': 1,
#  'Gaze eccentricity': 1,
#  'SHRP 2 naturalistic driving': 1,
#  'Driver maneuver': 1,
#  'Rear-end events': 1,
#  'Automated vehicle': 1,
#  'Safety evaluation': 1,
#  'Safety implications': 1,
#  'Road test data': 1,
#  'Target crash population': 1,
#  'Failure risk': 1,
#  'Evaluation metric': 1,
#  'Pre-event analysis': 1,
#  'Anomaly detection': 1,
#  'Video surveillance system': 1,
#  'Vehicle occupant injury': 1,
#  'High-resolution': 1,
#  'Event-based data': 1,
#  'XGBoost classifiers': 1,
#  'Human–autonomy interaction': 1,
#  'Human–robot interaction': 1,
#  'Trip features': 1,
#  'Driving characteristics': 1,
#  'Geometric features': 1,
#  'Speeding duration': 1,
#  'Speeding pattern': 1,
#  'Driving style': 1,
#  'Driving maneuver detection': 1,
#  'Driving tasks': 1,
#  '-means clustering': 1,
#  'Principal component analysis (PCA)': 1,
#  'Crowdsourcing data': 1,
#  'Traffic accidents post-impact': 1,
#  'Sequential prediction': 1,
#  'Lane change detection': 1,
#  'eXtrem gradient boosting': 1,
#  'Hit-and-run': 1,
#  'Road accident': 1,
#  'Vehicle type prediction': 1,
#  'Linear discriminant analysis': 1,
#  'k-Nearest neighbor': 1,
#  'Cross validation': 1,
#  'Road user safety': 1,
#  'Driver drowsiness': 1,
#  'Long short term memory': 1,
#  'Convolutional LSTM': 1,
#  'Eye detection': 1,
#  'Non-invasive': 1,
#  'Random forest (RF)': 1,
#  'Support vector machine (SVM)': 1,
#  'Safety performance functions': 1,
#  'Tobit model': 1,
#  'Data mining methods': 1,
#  'Highway safety manual': 1,
#  'Vehicle trajectories': 1,
#  'Gaussian mixture model': 1,
#  'Recommendation system': 1,
#  'Assessment system': 1,
#  'Foggy weather conditions': 1,
#  'Data mining techniques': 1,
#  'Association rules mining': 1,
#  'Lane-keeping': 1,
#  'Limited visibility': 1,
#  'Traffic crash severity prediction': 1,
#  'Multinomial logit': 1,
#  'Nearest neighbor classification': 1,
#  'Crash costs': 1,
#  'Data annotation': 1,
#  'Crowdsourcing': 1,
#  'Validity': 1,
#  'Dash cam': 1,
#  'Significant factor': 1,
#  'Highway crash': 1,
#  'Identification': 1,
#  'Ensemble tree': 1,
#  'Accident investigations': 1,
#  'In-vehicle systems': 1,
#  'Severity classification': 1,
#  'Stacking model': 1,
#  'Random Forests': 1,
#  'Adaptive Boosting': 1,
#  'Gradient Boosting Decision Tree': 1,
#  'Driving distraction': 1,
#  'Upper extremity kinematics': 1,
#  'Multi-class classification': 1,
#  'Real-time crash prediction': 1,
#  'Automatic vehicle identification': 1,
#  'Flow composition': 1,
#  'Urban expressway safety management': 1,
#  'Crash risk evaluation': 1,
#  'Threshold selection method': 1,
#  'Cross-entropy': 1,
#  'Between-class variance': 1,
#  'Monitoring': 1,
#  'ANN': 1,
#  'Adaptive learning': 1,
#  'Inter-individual variability': 1,
#  'Autonomous technology disengagements': 1,
#  'Hybrid models': 1,
#  'Elderly drivers': 1,
#  'Fixed object crashes': 1,
#  'Mobile laser scanning': 1,
#  'Point cloud processing': 1,
#  'Safety assessment': 1,
#  'Geographic information system': 1,
#  'In-vehicle collision avoidance assistance': 1,
#  'Warning strategy/specificity': 1,
#  'Hazardous urban incidents': 1,
#  'Driver behavior/subjective acceptance evaluation': 1,
#  'Bivariate extreme value theory': 1,
#  'Video-based vehicle trajectory': 1,
#  'Traffic conflict': 1,
#  'Lane change impact': 1,
#  'Helmet use detection': 1,
#  'Injury prevention': 1,
#  'Urban roads': 1,
#  'Road intersection': 1,
#  'Crash severity level': 1,
#  '5-min flow': 1,
#  'Short-term data': 1,
#  'Generalized linear mixed model': 1,
#  'Physiological measurement': 1,
#  'Behavioral measurement': 1,
#  'Driving performance and activity': 1,
#  'Crash prediction model': 1,
#  'TrAdaBoost.R2': 1,
#  'Calibration factor': 1,
#  'ITS': 1,
#  'Real-time crash prediction model': 1,
#  'Design pathway': 1,
#  'Universal design requirements': 1,
#  'Adverse weather effects': 1,
#  'Balanced bagging': 1,
#  'xgBoost': 1,
#  'Fatal accidents': 1,
#  'Information measure': 1,
#  'Key factors': 1,
#  'Spatial-temporal perspective': 1,
#  'Congestion': 1,
#  'Freeways': 1,
#  'Recurrent neural network': 1,
#  'Multi-source data': 1,
#  'Spatiotemporal': 1,
#  'Lane changing risk': 1,
#  'Feature selection': 1,
#  'Crash potential index': 1,
#  'Resampling method': 1,
#  'Cell phone': 1,
#  'Human-machine interactions': 1,
#  'Inattention': 1,
#  'UX': 1,
#  'Gradient boosting tree': 1,
#  'Rule extraction': 1,
#  'Secondary incidents': 1,
#  'Injury autocoding': 1,
#  'Rare categories': 1,
#  'Text classification': 1,
#  'More training data vs filtering': 1,
#  'Human-machine systems': 1,
#  'Context-aware system': 1,
#  'Crash severity estimation': 1,
#  'Collision mitigation': 1,
#  'Pre-triggering': 1,
#  'Vehicle safety': 1,
#  'Partial automation': 1,
#  'Lateral scenarios': 1,
#  'Conditionally automated vehicles': 1,
#  'Virtual Reality': 1,
#  'Head-Mounted Display': 1,
#  'Take-over request': 1,
#  'Recovery of function': 1,
#  'Mental Health Recovery': 1,
#  'Decision support techniques': 1,
#  'Statistical learning': 1,
#  'Expressway safety': 1,
#  'Safety resilience of traffic': 1,
#  'Vehicle moving violation': 1,
#  'Critical instantaneous decision events': 1,
#  'Permutation entropy': 1,
#  'Cube searching algorithm': 1,
#  'Mixed-flow intersections': 1,
#  'Big data': 1,
#  'Trip pattern': 1,
#  'Taxi GPS data': 1,
#  'Crashes': 1,
#  'Secondary crashes': 1,
#  'Complementary log-log': 1,
#  'Likelihood': 1,
#  'Real-time traffic data': 1,
#  'Dynamic Bayesian Network': 1,
#  'Driver safety': 1,
#  'Uncertainty': 1,
#  'Linear referencing': 1,
#  'GIS': 1,
#  'Lane changing': 1,
#  'Gap acceptance': 1,
#  'Hazard-duration model': 1,
#  'Infrared oculograph': 1,
#  'Pedestrian crash frequency': 1,
#  'Non-linear effects': 1,
#  'Connected driverless vehicles': 1,
#  'Connected autonomous vehicles': 1,
#  'Principal components analysis': 1,
#  'Longitudinal prediction': 1,
#  'Risk prediction': 1,
#  'Multi-stage collision avoidance assistance': 1,
#  'Driver behavior/subjective rating': 1,
#  'Safety-critical situations': 1,
#  'Repeated event exposure': 1,
#  'Truck driver': 1,
#  'Digital tachograph data': 1,
#  'PCA': 1,
#  'DBSCAN': 1,
#  'Multilevel modeling': 1,
#  'Safety Surrogate Measures': 1,
#  'traffic conflicts': 1,
#  'data integration architecture': 1,
#  'Regional–Convolution Neural Network (R-CNN)': 1,
#  'Deep Neural Network (DNN)': 1,
#  'Injury severity classification': 1,
#  'Data analytics': 1,
#  'Automated vehicle safety': 1,
#  'Automated vehicles': 1,
#  'Disengagement': 1,
#  'Human factor': 1,
#  'Secondary crash': 1,
#  'Crash prevention': 1,
#  'Traffic incident': 1,
#  'Cox model': 1,
#  'Roadside design': 1,
#  'Forgiving roadside': 1,
#  'Rear-end crashes': 1,
#  'Crash potential': 1,
#  'Locational analysis': 1,
#  'Near-crash behavior': 1,
#  'Multinomial Logit model': 1,
#  'Deep learning methods': 1,
#  'Long short-term memory networks': 1,
#  'Traffic condition': 1,
#  'Different temporal resolutions': 1,
#  'Poisson-Tweedie distribution': 1,
#  'Geometric Poisson model': 1,
#  'Poisson inverse Gaussian model': 1,
#  'Dispersion parameter': 1,
#  'Sleepiness': 1,
#  'Circadian rhythm': 1,
#  'Driving education': 1,
#  'Accident classification': 1,
#  'Model Selection': 1,
#  'Heuristics': 1,
#  'Characteristics of Data': 1,
#  'Negative Binomial': 1,
#  'Negative Binomial Lindley': 1,
#  'Aging bicyclists and pedestrians': 1,
#  'Multivariate random parameter Tobit model': 1,
#  'Spatiotemporal variations': 1,
#  'Crash rate difference': 1,
#  'Population factor': 1,
#  'Theory of reasoned action': 1,
#  'Safety behavior': 1,
#  'Working at height': 1,
#  'Mindfulness': 1,
#  'Income': 1,
#  'Biological sex': 1,
#  'Using smartphones while driving': 1,
#  'Bayesian combiner': 1,
#  'Driver fatigue': 1,
#  'Modular structure': 1,
#  'Performance optimisation': 1,
#  'Particle swarm optimisation': 1,
#  'Negotiation': 1,
#  'Self-driving vehicles': 1,
#  'Vehicle–pedestrian interaction': 1,
#  'Pedestrian risk': 1,
#  'Calling': 1,
#  'Behavioural adaptation': 1,
#  'Browsing': 1,
#  'Texting': 1,
#  'spatial analysis': 1,
#  'crash analysis': 1,
#  'study characteristics': 1,
#  'areal units': 1,
#  'variable selection': 1,
#  'NLPCA': 1,
#  'SOM': 1,
#  'Sight obstruction': 1,
#  'Warning design': 1,
#  'Specific warnings': 1,
#  'Augmented reality': 1,
#  'Spatial referencing': 1,
#  'Specificity': 1,
#  'Secondary accident': 1,
#  'Spatiotemporal Gap': 1,
#  'BP neural network': 1,
#  'LSSVM': 1,
#  'Incident management': 1,
#  'Driving behavior recognition': 1,
#  'Car-following behavior': 1,
#  'K-means': 1,
#  'Rural local roads': 1,
#  'Rural local intersections': 1,
#  'Low-volume county roads': 1,
#  'Low sample mean': 1,
#  'Bivariate negative binomial model': 1,
#  'Bivariate ordered probit model': 1,
#  'Crash rates': 1,
#  'Collision types': 1,
#  'Multivariate Tobit model': 1,
#  'Random parameters': 1,
#  'Full bayesian estimation': 1,
#  'Time series analysis': 1,
#  'Statistical methods': 1,
#  'Econometric methods': 1,
#  'Computational intelligence models': 1,
#  'Crash data modeling': 1,
#  'Traffic law enforcement': 1,
#  'Transportation demand management': 1,
#  'Driver performance monitoring': 1,
#  'Physiological data': 1,
#  'Take-over': 1,
#  'Heart rate': 1,
#  'Pupil diameter': 1,
#  'Autonomous vehicle': 1,
#  'Accident prevention': 1,
#  'Probabilistic neural network': 1,
#  'Adaptive signal control technology crashes': 1,
#  'Spatial transferability': 1,
#  'Random parameters ordered probit models': 1,
#  'Risk estimation': 1,
#  'Speed control': 1,
#  'Risk map': 1,
#  'Risk minimization': 1,
#  'Eco-safe driving': 1,
#  'In-vehicle HMI': 1,
#  'Glance behaviour': 1,
#  'Traffic situation': 1,
#  'Roadway alignment': 1,
#  'Weather condition': 1,
#  'Interaction effect': 1,
#  'Spatio-Temporal model': 1,
#  'Motor carrier safety': 1,
#  'Crash rate': 1,
#  'Variable selection': 1,
#  'Classification and Regression Tree': 1,
#  'Mapping knowledge domain': 1,
#  'Visualization': 1,
#  'VOSviewer': 1,
#  'Sci2 Tool': 1,
#  'Floating car trajectory': 1,
#  'Traffic platoon': 1,
#  'Crash propensity prediction': 1,
#  'Binary logistic regression': 1,
#  'Highway-Rail Grade Crossing Consolidation': 1,
#  'Closure Rating Formula': 1,
#  'XGboost': 1,
#  'Fault': 1,
#  'Recovery': 1,
#  'Road trauma': 1,
#  'Transport injury': 1,
#  'Pain': 1,
#  'Mental health': 1,
#  'PTSD': 1,
#  'Depression': 1,
#  'Anxiety': 1,
#  'Toll plaza': 1,
#  'Diverging area': 1,
#  'Non-Parametric model': 1,
#  'Driving behavior state': 1,
#  'Electroencephalography': 1,
#  'Independent component analysis': 1,
#  'Feature extraction': 1,
#  'Multi-class imbalanced learning framework': 1,
#  'Injury severity pattern': 1,
#  'Sensitivity analysis': 1,
#  'Key risk indicator': 1,
#  'Risk exposure': 1,
#  'Pre-accident risk': 1,
#  'Vehicle risk': 1,
#  'Naturalistic driving studies': 1,
#  'Event-based volatility': 1,
#  'Vehicular jerk': 1,
#  'Crash propensity': 1,
#  'Fixed and random parameters': 1,
#  'Logit models': 1,
#  'Road infrastructure': 1,
#  'Traffic complexity': 1,
#  'Mobile phone distraction': 1,
#  'High-fidelity driving simulator': 1,
#  'Take-Over': 1,
#  'Modeling': 1,
#  'Regression': 1,
#  'Deceleration curve': 1,
#  'Cluster analysis': 1,
#  'Driver braking behavior profile': 1,
#  'Dynamic time warping': 1,
#  'Microscopic traffic flow variables': 1,
#  'Heterogeneous effects': 1,
#  'Latent class logit': 1,
#  'Path analysis': 1,
#  'SHAP': 1,
#  'Real time data': 1,
#  'Man-machine interaction': 1,
#  'Driver modelling': 1,
#  'Driver assistance': 1,
#  'Active road safety': 1,
#  'Driving automation': 1,
#  'Instrumented vehicles': 1,
#  'Cross-country experiments': 1,
#  'Rail safety': 1,
#  'Rail accidents': 1,
#  'Contributing factors': 1,
#  'Driver reliability': 1,
#  'Driving task analysis': 1,
#  'Driver errors': 1,
#  'Driver observation': 1,
#  'Driver assistance systems': 1,
#  'Intersection design': 1,
#  'Theory of Planned Behaviour (TPB)': 1,
#  'Perceived susceptibility': 1,
#  'Causal factor': 1,
#  'Communication': 1,
#  'Failure': 1,
#  'Systemic': 1,
#  'Decision styles (DS)': 1,
#  'Efficiency': 1,
#  'Performance failure': 1,
#  'Health': 1,
#  'Environment (HSE)': 1,
#  'Optimization': 1,
#  'Data envelopment analysis (DEA)': 1,
#  'Oil refinery': 1,
#  'Quantitative risk assessment': 1,
#  'Parameter uncertainty': 1,
#  "Alzheimer's disease": 1,
#  'Occupational therapy': 1,
#  'Driving fitness': 1,
#  'Medical condition': 1,
#  'Maritime traffic safety': 1,
#  'Ship accidents': 1,
#  'Data quality': 1,
#  'Expert knowledge': 1,
#  'Text data': 1,
#  'Injury epidemiology': 1,
#  'Job demands–resources model': 1,
#  'Emotional exhaustion': 1,
#  'Safety compliance': 1,
#  'Safety outcomes': 1,
#  'Accident-mapping': 1,
#  'Pattern-matching': 1,
#  'Fault tree': 1,
#  'Steel construction projects': 1,
#  'Safety risk': 1,
#  'M5 model tree': 1,
#  'Random effect negative binomial model': 1,
#  'Dynamic event tree': 1,
#  'Probabilistic safety assessment': 1,
#  'Dynamic safety assessment': 1,
#  'Fuzzy': 1,
#  'Possibilistic': 1,
#  'Vulnerable road users': 1,
#  'Horses': 1,
#  'Countermeasures': 1,
#  'Safety-climate level': 1,
#  'Safety-climate strength': 1,
#  'Injury rate': 1,
#  'Childhood injury': 1,
#  'Pedestrian': 1,
#  'Parental modelling': 1,
#  'Road behaviour': 1,
#  'Experience-based analysis (EBA)': 1,
#  'Feeling of invulnerability': 1,
#  'Feeling of control': 1,
#  'Occupational accidents': 1,
#  'Work accidents': 1,
#  'Occupational injury': 1,
#  'Rules induction': 1,
#  'Technological development': 1,
#  'Accident pattern': 1,
#  'Poisson regression': 1,
#  'Mining industry': 1,
#  'Angle crash': 1,
#  'Unsignalized intersections': 1,
#  'Action research': 1,
#  'Acceptability': 1,
#  'Appropriation': 1,
#  'Innovation': 1,
#  'Driving experience': 1,
#  'Novice drivers': 1,
#  'In-vehicle displays': 1,
#  'Safety culture': 1,
#  'Systems thinking': 1,
#  'Safety model.': 1,
#  'Macroergonomics': 1,
#  'Sociotechnical systems theory': 1,
#  'Mesoergonomics': 1,
#  'Pedestrian gestures': 1,
#  'Yield rate': 1,
#  'Persuasion': 1,
#  'Road and street crossings': 1,
#  'Uncontrolled mid-block crosswalks': 1,
#  'Driver inattention': 1,
#  'Eye movements': 1,
#  'Feedback': 1,
#  'Trip-report': 1,
#  'In-vehicle distractions': 1,
#  'Post-drive information': 1,
#  'Recurrent scenarios': 1,
#  'Occupational accident with movement disturbance': 1,
#  'Accident investigation': 1,
#  'Mining': 1,
#  'Human Factors Analysis and Classification System (HFACS)': 1,
#  'Cause of injury': 1,
#  'Work injury': 1,
#  'Vulnerability': 1,
#  'Prevention': 1,
#  'Observational study': 1,
#  'Video processing': 1,
#  'Recently qualified drivers': 1,
#  'Driver training': 1,
#  'Overtaking': 1,
#  'Methodology': 1,
#  'Multi-lane roads': 1,
#  'Discipulus': 1,
#  'Vehicle heading': 1,
#  'Lane deviation': 1,
#  'Drowsy driver detection': 1,
#  'Yellow indication': 1,
#  'Run/stop behavior': 1,
#  'Diagnosis': 1,
#  'Fuzzy systems': 1,
#  'Marine engineering': 1,
#  'Uncertainty analysis': 1,
#  'Genetic algorithms': 1,
#  'Health data': 1,
#  ...}

# %% [markdown]
# # Algorithms

# %% [markdown]
# ## Create Dictionary of Algorithms

# %%
Algorithms = {
    'Bayesian': ['Bayesian Logistics Regression', 'Bayes'],
    'XGBoost':['XGBoost', 'XGB'],
    'LSTM: Long Short-Term Memory': ['Long Short-term Memory'],
    'Decision Jungle': ['Decision Jungle'],
    'Random Forest':['Random Forest'],
    'RSF: Random Survival Forest': ['Random Survival Forest'],
    'Ensemble': ['Ensemble'],
    'Deep Learning': ['Deep Learning', 'deep-learning'],
    'ANN:  Artificial Neural Network': ['Artificial Neural Network'],
    'IGA: Intelligent Genetic Algorithm': ['Intelligent Genetic Algorithm'],
    'SMO: Synthetic Minority Oversampling': ['synthetic minority oversampling'],
    'MDU: Maximum Dissimilarity Undersampling': ['maximum dissimilarity undersampling'],
    'Statistical Learning': ['Statistical learning'],
    'CIF: Cumulative Incidence Function': ['Cumulative Incidence Function'],
    'VIMP: Variable Importance': ['Variable Importance'],
    'Marginal Effect Analysis': ['Marginal Effect Analysis'],
    'Mixed Methods': ['Mixed Methods'],
    'Logistic Regression': ['Logistic Regression'],
    'Dynamic Bayesian Network': ['Dynamic Bayesian'],
    'CNN:  Convolutional Neural Network': ['Convolutional Neural Network', 'CNN'],
    'Neural Network': ['Neural Network'],
    'Feature Extraction': ['Feature Extraction'],
    'Shapley': ['Shapley'],
    'Convex Hull Algorithm': ['Convex Hull'],
    'Dimensionality Reduction': ['Dimensionality Reduction'],
    't-SNE': ['t-SNE'],
}

# %% [markdown]
# ## Find Mentions of Algorithms in Abstracts or Keywords

# %%
for alg in Algorithms:
    P[alg] = P['abstract'].str.contains('|'.join(Algorithms[alg]), case=False) | P['keywords'].str.contains('|'.join(Algorithms[alg]), case=False)

# %% [markdown]
# ## Count Mentions of Algorithms in Abstracts or Keywords

# %%
A = P[Algorithms.keys()].sum()
A.sort_values(ascending=False)
# Out:
# Bayesian                                    45
# Neural Network                              33
# Random Forest                               28
# Logistic Regression                         19
# Deep Learning                               16
# ANN:  Artificial Neural Network              9
# XGBoost                                      9
# LSTM: Long Short-Term Memory                 8
# CNN:  Convolutional Neural Network           8
# Ensemble                                     5
# Feature Extraction                           5
# SMO: Synthetic Minority Oversampling         4
# Statistical Learning                         4
# VIMP: Variable Importance                    4
# Dynamic Bayesian Network                     3
# Shapley                                      2
# Dimensionality Reduction                     1
# Convex Hull Algorithm                        1
# CIF: Cumulative Incidence Function           1
# Mixed Methods                                1
# Marginal Effect Analysis                     1
# MDU: Maximum Dissimilarity Undersampling     1
# IGA: Intelligent Genetic Algorithm           1
# RSF: Random Survival Forest                  1
# Decision Jungle                              1
# t-SNE                                        1
# dtype: int64

# %% [markdown]
# # Analysis Tools

# %% [markdown]
# ## Create Dictionary of Analysis Tools

# %%
Analysis_Tools = {
    'Sensitivity': ['Sensitivity'],
    'Area under Curve': ['Area under Curve'],
    'False Alarm Rate': ['False Alarm Rate'],
    'Accuracy': ['accuracy'],
    'Precision': ['macro-average precision'], 
    'Recall': ['macro-average recall'], 
    'Geometric Mean': ['geometric mean'],
    'Hyperparameters': ['Hyperparameter'],
    'Spearman': ['Spearman'],
    'Aggregated Gain': ['Aggregated Gain'],
    'Time Dependencies': ['Time dependencies'],
    'Temporal': ['Temporal'],
    'Kinematic': ['Kinematic'],
    'Visualization': ['Visualization'],
    'Second Highway Research Program (Data Set)': ['Second Highway Research Program', 'SHRP2'],
    'F1 Loss Function': ['F1'],
    'Connected Vehicles': ['Connected Vehicles']
}

# %% [markdown]
# ## Find Mentions of Analysis Tools in Abstracts or Keywords

# %%
for alg in Analysis_Tools:
    P[alg] = P['abstract'].str.contains('|'.join(Analysis_Tools[alg]), case=False) | P['keywords'].str.contains('|'.join(Analysis_Tools[alg]), case=False)

# %% [markdown]
# ## Count Mentions of Analysis Tools in Abstracts or Keywordes

# %%
A = P[Analysis_Tools.keys()].sum()
A.sort_values(ascending=False)
# Out:
# Accuracy                                      72
# Sensitivity                                   29
# Temporal                                      23
# Kinematic                                     10
# Second Highway Research Program (Data Set)     8
# Connected Vehicles                             8
# False Alarm Rate                               6
# Visualization                                  4
# F1 Loss Function                               4
# Geometric Mean                                 2
# Hyperparameters                                2
# Aggregated Gain                                2
# Area under Curve                               1
# Time Dependencies                              1
# Recall                                         1
# Precision                                      1
# Spearman                                       1
# dtype: int64

# %% [markdown]
# # Authors

# %% [markdown]
# ## Sort Authors by Frequency

# %%
P['author'] = P['author'].fillna('None')
A = [ x.split(' and ') for x in P['author'].tolist() ]
B = [item for sublist in A for item in sublist]
C = {x:B.count(x) for x in B}
D = dict(sorted(C.items(), key=lambda item: item[1], reverse=True))
D
# Out:
# {'Mohamed Abdel-Aty': 14,
#  'Zhibin Li': 7,
#  'Junhua Wang': 6,
#  'Rongjie Yu': 6,
#  'Pan Liu': 6,
#  'Asad J. Khattak': 5,
#  'Ting Fu': 5,
#  'Mohammed Quddus': 5,
#  'Jinghui Yuan': 5,
#  'Mark King': 5,
#  'Chengcheng Xu': 5,
#  'Dominique Lord': 4,
#  'Helai Huang': 4,
#  'Qing Cai': 4,
#  'Oscar Oviedo-Trespalacios': 4,
#  'None': 4,
#  'George Yannis': 3,
#  'X. Jessie Yang': 3,
#  'Mohamed M. Ahmed': 3,
#  'Jie He': 3,
#  'Alfonso Montella': 3,
#  'Xiaomeng Li': 3,
#  'Andry Rakotonirainy': 3,
#  'Pei Li': 3,
#  'Simon Washington': 3,
#  'Zulqarnain H. Khattak': 3,
#  'Michael D. Fontaine': 3,
#  'Yiik Diew Wong': 3,
#  'Xiupeng Shi': 3,
#  'Kirolos Haleem': 3,
#  'William J. Horrey': 3,
#  'Matthias Schlögl': 3,
#  'Frederik Naujoks': 3,
#  'Priyanka Alluri': 3,
#  'Richard Forsyth': 3,
#  'Richard Wright': 3,
#  'Wei Wang': 3,
#  'Amirfarrokh Iranitalab': 2,
#  'Eleni I. Vlahogianni': 2,
#  'Mahama Yahaya': 2,
#  'Runhua Guo': 2,
#  'Xinguo Jiang': 2,
#  'Kamal Bashir': 2,
#  'Shiwei Xu': 2,
#  'Behram Wali': 2,
#  'Tarek Sayed': 2,
#  'Jaeyoung Lee': 2,
#  'Tianyang Luo': 2,
#  'Jianqiang Wang': 2,
#  'Samira Soleimani': 2,
#  'Michael Leitner': 2,
#  'Julius Codjoe': 2,
#  'Cheol Oh': 2,
#  'Md Nasim Khan': 2,
#  'Meng Li': 2,
#  'Yasir Ali': 2,
#  'Md. Mazharul Haque': 2,
#  'Zuduo Zheng': 2,
#  'Reuben Tamakloe': 2,
#  'Jungyeol Hong': 2,
#  'Dongjoo Park': 2,
#  'Xintong Yan': 2,
#  'Changjian Zhang': 2,
#  'Ziyang Liu': 2,
#  'Hao Zhang': 2,
#  'Filomena Mauriello': 2,
#  'Linchao Li': 2,
#  'Guangchuan Yang': 2,
#  'Mohamed Ahmed': 2,
#  'Eric Adomah': 2,
#  'Johanna Wörle': 2,
#  'Barbara Metz': 2,
#  'Martin Baumann': 2,
#  'Christos Katrakazas': 2,
#  'Loukas Dimitriou': 2,
#  'Andrew P. Tarko': 2,
#  'Atiyeh Vaezipour': 2,
#  'Md Mazharul Haque': 2,
#  'Lu Xing': 2,
#  'Thomas Karnowski': 2,
#  'Xin Zou': 2,
#  'Tianyi Chen': 2,
#  'Shile Zhang': 2,
#  'Siby Samuel': 2,
#  'Apostolos Ziakopoulos': 2,
#  'Zhen Gao': 2,
#  'Na Du': 2,
#  'Feng Zhou': 2,
#  'Li Li': 2,
#  'Yina Wu': 2,
#  'Thomas A. Dingus': 2,
#  'Anthony D. McDonald': 2,
#  'Emmanuel Kidando': 2,
#  'Angela E. Kitali': 2,
#  'Thobias Sando': 2,
#  'Yunlong Zhang': 2,
#  'Anik Das': 2,
#  'Riender Happee': 2,
#  'Yunjie Li': 2,
#  'Mengtao Zhu': 2,
#  'Yinhai Wang': 2,
#  'Yulan Liang': 2,
#  'Xuesong Wang': 2,
#  'Charlotte {Jacobé de Naurois}': 2,
#  'Christophe Bourdin': 2,
#  'Jean-Louis Vercher': 2,
#  'Susann Winkler': 2,
#  'Juela Kazazi': 2,
#  'Mark Vollrath': 2,
#  'Moinul Hossain': 2,
#  'Yasunori Muromachi': 2,
#  'Jie Bao': 2,
#  'Kirsten Vallmuur': 2,
#  'Mark Lehto': 2,
#  'Christian Purucker': 2,
#  'Alexandra Neukum': 2,
#  'Rainer Stütz': 2,
#  'John D. Lee': 2,
#  'Mark E. Howard': 2,
#  'Junyi Zhang': 2,
#  'Albert Gan': 2,
#  'Yang Miang Goh': 2,
#  'Gil Luria': 2,
#  'Sebastien Demmel': 2,
#  'Wolfgang Fastenmeier': 2,
#  'Joshua Stipancic': 2,
#  'Liu Yang': 2,
#  'Rui Ma': 2,
#  'Wei Guan': 2,
#  'Amir Bahador Parsa': 2,
#  'Homa Taghipour': 2,
#  'Sybil Derrible': 2,
#  'Abolfazl (Kouros) Mohammadian': 2,
#  'Michael G. Lenné': 2,
#  'David D. Clarke': 2,
#  'Linda Ng Boyle': 2,
#  'Charles B.A. Musselwhite': 2,
#  'Birsen Donmez': 2,
#  'Changxu Wu': 2,
#  'David D Clarke': 2,
#  'Arash Jahangiri': 2,
#  'Cong Chen': 2,
#  'Guohui Zhang': 2,
#  'Xuedong Yan': 2,
#  'Essam Radwan': 2,
#  'P.A. Hancock': 2,
#  'Neville A. Stanton': 2,
#  'Ola Svenson': 2,
#  'Ezra Hauer': 2,
#  'Henry S.R. Kao': 2,
#  'Yueng-hsiang Huang': 1,
#  'Yimin He': 1,
#  'Jin Lee': 1,
#  'Changya Hu': 1,
#  'Xiaoyu Guo': 1,
#  'Lingtao Wu': 1,
#  'Amin Keramati': 1,
#  'Pan Lu': 1,
#  'Danguang Pan': 1,
#  'Ying Huang': 1,
#  'Hilkka Grahn': 1,
#  'Tuomo Kujala': 1,
#  'Johanna Silvennoinen': 1,
#  'Aino Leppänen': 1,
#  'Pertti Saariluoma': 1,
#  'Li Song': 1,
#  'Wei Fan': 1,
#  'Dimitrios I. Tselentis': 1,
#  'H.E.C. {van der Wall}': 1,
#  'R.J. Doll': 1,
#  'G.J.P. {van Westen}': 1,
#  'I. Koopmans': 1,
#  'R.G. Zuiker': 1,
#  'J. Burggraaf': 1,
#  'A.F. Cohen': 1,
#  'Caroline Matara': 1,
#  'Muhammad Ijaz': 1,
#  'Liu lan': 1,
#  'Muhammad Zahid': 1,
#  'Arshad Jamal': 1,
#  'Kyung (Kate) Hyun': 1,
#  'Suman Kumar Mitra': 1,
#  'Kyungsoo Jeong': 1,
#  'Andre Tok': 1,
#  'Andrea D. Furlan': 1,
#  'Tara Kajaks': 1,
#  'Margaret Tiong': 1,
#  'Martin Lavallière': 1,
#  'Jennifer L. Campos': 1,
#  'Jessica Babineau': 1,
#  'Shabnam Haghzare': 1,
#  'Tracey Ma': 1,
#  'Brenda Vrkljan': 1,
#  'Numan Ahmad': 1,
#  'Qingfan Wang': 1,
#  'Shun Gan': 1,
#  'Wentao Chen': 1,
#  'Quan Li': 1,
#  'Bingbing Nie': 1,
#  'Mohamed Essa': 1,
#  'Yanqi Lian': 1,
#  'Guoqing Zhang': 1,
#  'Qiangqiang Shangguan': 1,
#  'Shou’en Fang': 1,
#  'Xiaocong Zhao': 1,
#  'Ren He': 1,
#  'Youngbin Lym': 1,
#  'Zhenhua Chen': 1,
#  'Mahdi Rezapour': 1,
#  'Khaled Ksaibati': 1,
#  'Milhan Moomen': 1,
#  'Ruikun Luo': 1,
#  'Yifan Weng': 1,
#  'Yifan Wang': 1,
#  'Paramsothy Jayakumar': 1,
#  'Mark J. Brudnak': 1,
#  'Victor Paul': 1,
#  'Vishnu R. Desaraju': 1,
#  'Jeffrey L. Stein': 1,
#  'Tulga Ersal': 1,
#  'Milad Haghani': 1,
#  'Michiel C.J. Bliemer': 1,
#  'Bilal Farooq': 1,
#  'Inhi Kim': 1,
#  'Zahra Shahhoseini': 1,
#  'Hamish MacDougall': 1,
#  'Keneth Morgan Kwayu': 1,
#  'Valerian Kwigizile': 1,
#  'Kevin Lee': 1,
#  'Jun-Seok Oh': 1,
#  'Jun Liu': 1,
#  'Xiaobing Li': 1,
#  'Sen Luan': 1,
#  'Xin Li': 1,
#  'Xiaolei Ma': 1,
#  'Jiajie Hu': 1,
#  'Ming-Chun Huang': 1,
#  'Xiong Yu': 1,
#  'Anshuman Sharma': 1,
#  'Mohammad Saifuzzaman': 1,
#  'Michelangelo-Santo Gulino': 1,
#  'Leonardo Di Gangi': 1,
#  'Alessio Sortino': 1,
#  'Dario Vangi': 1,
#  'Boshuai Qiao': 1,
#  'Ali Jazayeri': 1,
#  'John Ray B. Martinez': 1,
#  'Helen S. Loeb': 1,
#  'Christopher C. Yang': 1,
#  'Y. Alver': 1,
#  'P. Onelcin': 1,
#  'A. Cicekli': 1,
#  'M. Abdel-Aty': 1,
#  'Mariano Pernetti': 1,
#  'Maria {Rella Riccardi}': 1,
#  'Xiaojie Long': 1,
#  'Yuan-Wei Wu': 1,
#  'Tien-Pen Hsu': 1,
#  'Carlo G. Prato': 1,
#  'Yonggang Wang': 1,
#  'Shraddha Sagar': 1,
#  'Nikiforos Stamatiadis': 1,
#  'Samantha Wright': 1,
#  'Aaron Cambron': 1,
#  'Mengxia Jin': 1,
#  'Guangquan Lu': 1,
#  'Facheng Chen': 1,
#  'Xi Shi': 1,
#  'Haitian Tan': 1,
#  'Junda Zhai': 1,
#  'Athanasios Theofilatos': 1,
#  'Md Ashraful Islam': 1,
#  'Eleonora Papadimitriou': 1,
#  'Constantinos Antoniou': 1,
#  'Jae-Hong Kwon': 1,
#  'Gi-Hyoug Cho': 1,
#  'Yaobang Gong': 1,
#  'Shah Khalid Khan': 1,
#  'Nirajan Shiwakoti': 1,
#  'Peter Stasinopoulos': 1,
#  'Yilun Chen': 1,
#  'Sébastien Demmel': 1,
#  'Zubayer Islam': 1,
#  'Lei Han': 1,
#  'Hui Zhang': 1,
#  'Thiago Christiano Silva': 1,
#  'Marcela T. Laiz': 1,
#  'Benjamin Miranda Tabak': 1,
#  'Ang Ji': 1,
#  'David Levinson': 1,
#  'Kamal Jetto': 1,
#  'Zineb Tahiri': 1,
#  'Abdelilah Benyoussef': 1,
#  'Abdallah {El Kenz}': 1,
#  'Cheng Yuan': 1,
#  'Diwas Thapa': 1,
#  'Sabyasachee Mishra': 1,
#  'Yi Lin': 1,
#  'Hailong Jing': 1,
#  'Bin Ran': 1,
#  'Dongye Sun': 1,
#  'Ashutosh Arun': 1,
#  'Ashish Bhaskar': 1,
#  'Yikai Chen': 1,
#  'Christopher N. Watling': 1,
#  'Md {Mahmudul Hasan}': 1,
#  'Grégoire S. Larue': 1,
#  'Wan Li': 1,
#  'Hai L. Vu': 1,
#  'Yaoyao Yang': 1,
#  'Jorge Ugan': 1,
#  'Pedro Mercader': 1,
#  'Jack Haddad': 1,
#  'Ina Othersen': 1,
#  'Tracy Zafian': 1,
#  'Alyssa Ryan': 1,
#  'Ravi Agrawal': 1,
#  'Michael Knodler': 1,
#  'Virginia Petraki': 1,
#  'Emre Kuşkapan': 1,
#  'M. Yasin Çodur': 1,
#  'Ahmet Atalay': 1,
#  'Wenbo Fan': 1,
#  'Yingfei Fan': 1,
#  'Raj Bridgelall': 1,
#  'Denver D. Tolliver': 1,
#  'Yichuan Peng': 1,
#  'Chongyi Li': 1,
#  'Ke Wang': 1,
#  'Md Adilur Rahim': 1,
#  'Hany M. Hassan': 1,
#  'Rocio {Suarez-del Fueyo}': 1,
#  'Mirko Junge': 1,
#  'Francisco Lopez-Valdes': 1,
#  'H. Clay Gabler': 1,
#  'Lucas Woerner': 1,
#  'Stefan Hiermaier': 1,
#  'Si Qiao': 1,
#  'Anthony {Gar-On Yeh}': 1,
#  'Mengzhu Zhang': 1,
#  'Xiang Yan': 1,
#  'Rico Krueger': 1,
#  'Prateek Bansal': 1,
#  'Prasad Buddhavarapu': 1,
#  'Niloufar Shirani-bidabadi': 1,
#  'Naveen Mallipaddi': 1,
#  'Michael Anderson': 1,
#  'Antonio Paez': 1,
#  'Hany Hassan': 1,
#  'Mark Ferguson': 1,
#  'Saiedeh Razavi': 1,
#  'Sherif Gaweesh': 1,
#  'Jeremiah Roland': 1,
#  'Peter D. Way': 1,
#  'Connor Firat': 1,
#  'Thanh-Nam Doan': 1,
#  'Mina Sartipi': 1,
#  'Rafael C. Goncalves': 1,
#  'Tyron L. Louw': 1,
#  'Manuela Quaresma': 1,
#  'Ruth Madigan': 1,
#  'Natasha Merat': 1,
#  'Can Zhao': 1,
#  'Xin Pei': 1,
#  'Zhiheng Li': 1,
#  'Fei-Yue Wang': 1,
#  'Xiangbin Wu': 1,
#  'Ramin Arvin': 1,
#  'Hairong Qi': 1,
#  'Farman Ali': 1,
#  'Amjad Ali': 1,
#  'Muhammad Imran': 1,
#  'Rizwan Ali Naqvi': 1,
#  'Muhammad Hameed Siddiqi': 1,
#  'Kyung-Sup Kwak': 1,
#  'Xiaolin Song': 1,
#  'Yangang Yin': 1,
#  'Haotian Cao': 1,
#  'Song Zhao': 1,
#  'Mingjun Li': 1,
#  'Binlin Yi': 1,
#  'Ou Zheng': 1,
#  'Burak Yiğit Katanalp': 1,
#  'Ezgi Eren': 1,
#  'Naomi J. Dunn': 1,
#  'Susan Soccolich': 1,
#  'Abhijit Sarkar': 1,
#  'Jeffrey S. Hickman': 1,
#  'Wenyan Huang': 1,
#  'Tobias Vogelpohl': 1,
#  'Gustav Markkula': 1,
#  'Soheil Sohrabi': 1,
#  'Ali Khodadadi': 1,
#  'Seyedeh Maryam Mousavi': 1,
#  'Bahar Dadashova': 1,
#  'Anima Pramanik': 1,
#  'Sobhan Sarkar': 1,
#  'J. Maiti': 1,
#  'Boniphace Kutela': 1,
#  'Mahyar Ghorbanzadeh': 1,
#  'Alican Karaer': 1,
#  'Mohammadreza Koloushani': 1,
#  'Ren Moses': 1,
#  'Eren E. Ozguven': 1,
#  'Elizabeth M. Pulver': 1,
#  'Dawn M. Tilbury': 1,
#  'Lionel P. Robert': 1,
#  'Anuj K. Pradhan': 1,
#  'Xiaoqiang Kong': 1,
#  'Subasish Das': 1,
#  'Kartikeya Jha': 1,
#  'Yongfeng Ma': 1,
#  'Wenlu Li': 1,
#  'Kun Tang': 1,
#  'Ziyu Zhang': 1,
#  'Shuyan Chen': 1,
#  'Yunduan Lin': 1,
#  'Ruimin Li': 1,
#  'Alok Nikhil Jha': 1,
#  'Niladri Chatterjee': 1,
#  'Geetam Tiwari': 1,
#  'Azhar Quddus': 1,
#  'Ali {Shahidi Zandi}': 1,
#  'Laura Prest': 1,
#  'Felix J.E. Comeau': 1,
#  'Ahmed Farid': 1,
#  'Zihan Hong': 1,
#  'Ying Chen': 1,
#  'Yang Wu': 1,
#  'Ali Ghasemzadeh': 1,
#  'Aemal Khattak': 1,
#  'Christopher D.D. Cabrall': 1,
#  'Zhenji Lu': 1,
#  'Miltos Kyriakidis': 1,
#  'Laura Manca': 1,
#  'Chris Dijksterhuis': 1,
#  'Joost {de Winter}': 1,
#  'Dongfang Ma': 1,
#  'Ziqiang Zeng': 1,
#  'Osama A. Osman': 1,
#  'Mustafa Hajij': 1,
#  'Sogand Karbalaieali': 1,
#  'Sherif Ishak': 1,
#  'Jinjun Tang': 1,
#  'Jian Liang': 1,
#  'Chunyang Han': 1,
#  'Boxuan Zhong': 1,
#  'Clayton Hutmacher': 1,
#  'Xu Xu': 1,
#  'Franco Basso': 1,
#  'Leonardo J. Basso': 1,
#  'Raul Pezoa': 1,
#  'Kui Yang': 1,
#  'Lifang Xue': 1,
#  'Clément Bougard': 1,
#  'Francesca Favarò': 1,
#  'Sky Eurich': 1,
#  'Nazanin Nader': 1,
#  'Amir Mohammadian Amiri': 1,
#  'Amirhossein Sadri': 1,
#  'Navid Nadimi': 1,
#  'Moe Shams': 1,
#  'Mario Soilán': 1,
#  'Belén Riveiro': 1,
#  'Ana Sánchez-Rodríguez': 1,
#  'Pedro Arias': 1,
#  'Chen Wang': 1,
#  'Yulu Dai': 1,
#  'Tong Liu': 1,
#  'Felix Wilhelm Siebert': 1,
#  'Hanhe Lin': 1,
#  'Wen-Hua Chen': 1,
#  'L. Mussone': 1,
#  'M. Bassani': 1,
#  'P. Masci': 1,
#  'Anca Stratulat': 1,
#  'Emmanuelle Diaz': 1,
#  'Dongjie Tang': 1,
#  'Xiaohan Yang': 1,
#  'Mohammed A. Quddus': 1,
#  'Soumik Nafis Sadeek': 1,
#  'Dan Halbersberg': 1,
#  'Boaz Lerner': 1,
#  'Zeyang Cheng': 1,
#  'Jian Lu': 1,
#  'Yunxuan Li': 1,
#  'Satish V. Ukkusuri': 1,
#  'Verity Truelove': 1,
#  'Hyoshin Park': 1,
#  'Ali Haghani': 1,
#  'Michael A. Knodler': 1,
#  'Gaurav Nanda': 1,
#  'Dennis Böhmländer': 1,
#  'Tobias Dirndorfer': 1,
#  'Ali H. Al-Bayatti': 1,
#  'Thomas Brandmeier': 1,
#  'Katharina Wiedemann': 1,
#  'Stefan Wolter': 1,
#  'Reid Steiger': 1,
#  'Daniele Sportillo': 1,
#  'Alexis Paljic': 1,
#  'Luciano Ojeda': 1,
#  'Esther Smits': 1,
#  'Charlotte Brakenridge': 1,
#  'Elise Gane': 1,
#  'Jacelle Warren': 1,
#  'Michelle Heron-Delaney': 1,
#  'Justin Kenardy': 1,
#  'Venerina Johnston': 1,
#  'Gregor Laaha': 1,
#  'Michael Melcher': 1,
#  'Yumeng Kong': 1,
#  'Yanning Wei': 1,
#  'Keping Li': 1,
#  'Keshuang Tang': 1,
#  'Xiao Qin': 1,
#  'Huaguo Zhou': 1,
#  'Henrick Haule': 1,
#  'Richard Lentz': 1,
#  'Chris Schwarz': 1,
#  'Timothy L. Brown': 1,
#  'Md. {Mazharul Haque}': 1,
#  'Mehmet Yildirimoglu': 1,
#  'Michael L. Lee': 1,
#  'Clare Anderson': 1,
#  'Michael S. Shreeve': 1,
#  'Conor S. O’Brien': 1,
#  'Charles A. Czeisler': 1,
#  'Chuan Ding': 1,
#  'Peng Chen': 1,
#  'Junfeng Jiao': 1,
#  'Yaoyuan V. Tan': 1,
#  'Michael R. Elliott': 1,
#  'Carol A.C. Flannagan': 1,
#  'Michael Zhi-Feng Li': 1,
#  'Chandrasekar Palanisamy': 1,
#  'Chen Chai': 1,
#  'Tuqiang Zhou': 1,
#  'Nicolette Formosa': 1,
#  'Stephen Ison': 1,
#  'Heejin Jeong': 1,
#  'Youngchan Jang': 1,
#  'Patrick J. Bowman': 1,
#  'Neda Masoud': 1,
#  'Song Wang': 1,
#  'Zhixia Li': 1,
#  'Hong Yang': 1,
#  'Zhenyu Wang': 1,
#  'Kun Xie': 1,
#  'Kaan Ozbay': 1,
#  'Marianna Imprialou': 1,
#  'Carlos Roque': 1,
#  'Mohammad Jalayer': 1,
#  'Katerina Stylianou': 1,
#  'Mohamed A. Abdel-Aty': 1,
#  'Feifeng Jiang': 1,
#  'Kwok Kit Richard Yuen': 1,
#  'Eric Wai Ming Lee': 1,
#  'Dibakar Saha': 1,
#  'Eric Dumbaugh': 1,
#  'Pasquale K. Alvaro': 1,
#  'Nicole M. Burnett': 1,
#  'Gerard A. Kennedy': 1,
#  'William Yu Xun Min': 1,
#  'Marcus McMahon': 1,
#  'Maree Barnes': 1,
#  'Melinda Jackson': 1,
#  'C.U. Ubeynarayana': 1,
#  'Mohammadali Shirazi': 1,
#  'Soma Sekhar Dhavala': 1,
#  'Srinivas Reddy Geedipally': 1,
#  'Mehmet Baran Ulak': 1,
#  'Eren Erman Ozguven': 1,
#  'Omer Arda Vanli': 1,
#  'Maxim A. Dulebenets': 1,
#  'Lisa Spainhour': 1,
#  'Chalani U. Ubeynarayana': 1,
#  'Karen Le Xin Wong': 1,
#  'Brian H.W. Guo': 1,
#  'Simon Höfling': 1,
#  'Kathrin Zeeb': 1,
#  'Erez Kita': 1,
#  'Hilal Al-libawy': 1,
#  'Ali Al-Ataby': 1,
#  'Waleed Al-Nuaimy': 1,
#  'Majid A. Al-Taee': 1,
#  'Surabhi Gupta': 1,
#  'Maria Vasardani': 1,
#  'Bharat Lohani': 1,
#  'Stephan Winter': 1,
#  'Miriam Rocha': 1,
#  'Michel Anzanello': 1,
#  'Felipe Caleffi': 1,
#  'Helena Cybis': 1,
#  'Gabrielli Yamashita': 1,
#  'Felix Schwarz': 1,
#  'Boya Liu': 1,
#  'Shuo Liu': 1,
#  'H. Michael Zhang': 1,
#  'Shixiong Jiang': 1,
#  'Thomas Hall': 1,
#  'Yanyong Guo': 1,
#  'Yao Wu': 1,
#  'Steven M. Lavrenz': 1,
#  'Konstantina Gkritza': 1,
#  'Yue Ke': 1,
#  'Moahd Alghuson': 1,
#  'Khaled Abdelghany': 1,
#  'Ahmed Hassan': 1,
#  'Mohamed Taher Alrefaie': 1,
#  'Stever Summerskill': 1,
#  'Thomas W Jackon': 1,
#  'Brian L. Smith': 1,
#  'Jiaqi Ma': 1,
#  'Hyunjin Park': 1,
#  'Tingting Huang': 1,
#  'Shuo Wang': 1,
#  'Anuj Sharma': 1,
#  'Huiying Wen': 1,
#  'Xuan Zhang': 1,
#  'Qiang Zeng': 1,
#  'N.N. Sze': 1,
#  'Jundi Liu': 1,
#  'Linda N. Boyle': 1,
#  'Ashis G. Banerjee': 1,
#  'Wen Long Yue': 1,
#  'Hai Le Vu': 1,
#  'Saleh R. Mousa': 1,
#  'Melita J. Giummarra': 1,
#  'Georgina Lau': 1,
#  'Genevieve Grant': 1,
#  'Belinda J. Gabbe': 1,
#  'Ye Li': 1,
#  'Xin Gu': 1,
#  'X. Shi': 1,
#  'Y.D. Wong': 1,
#  'M.Z.F. Li': 1,
#  'C. Chai': 1,
#  'Christian Gold': 1,
#  'Klaus Bengler': 1,
#  'Xiaoxia Xiong': 1,
#  'Meng Wang': 1,
#  'Yingfeng Cai': 1,
#  'Long Chen': 1,
#  'Haneen Farah': 1,
#  'Marjan Hagenzieker': 1,
#  'Yin Zheng': 1,
#  'Ali Movahedi': 1,
#  'R. Onken': 1,
#  'J.P. Feraric': 1,
#  'Luigi Pariota': 1,
#  'Gennaro Nicola Bifulco': 1,
#  'Francesco Galante': 1,
#  'Mark Brackstone': 1,
#  'Gemma J.M. Read': 1,
#  'Simon A. Moss': 1,
#  'Herbert Gstalter': 1,
#  'Kathryn Chorlton': 1,
#  'Mark Conner': 1,
#  'Samantha Jamson': 1,
#  'Jaime Santos-Reyes': 1,
#  'Alan N. Beard': 1,
#  'A. Azadeh': 1,
#  'Z. Mokhtari': 1,
#  'Z. Jiryaei Sharahi': 1,
#  'M. Zarrin': 1,
#  'Qiang Meng': 1,
#  'Jinxian Weng': 1,
#  'Xiaobo Qu': 1,
#  'David W. Eby': 1,
#  'Nina M. Silverstein': 1,
#  'Lisa J. Molnar': 1,
#  'David LeBlanc': 1,
#  'Geri Adler': 1,
#  'Maria Hänninen': 1,
#  'Feng Li': 1,
#  'Li Jiang': 1,
#  'Xiang Yao': 1,
#  'YongJuan Li': 1,
#  'Lipika Deka': 1,
#  'Sou-Sen Leu': 1,
#  'Ching-Miao Chang': 1,
#  'Gyanendra Singh': 1,
#  'S.N. Sachdeva': 1,
#  'Mahesh Pal': 1,
#  'D. Mercurio': 1,
#  'L. Podofillini': 1,
#  'E. Zio': 1,
#  'V.N. Dang': 1,
#  'Susan Chrysler': 1,
#  'Matthew Karlaftis': 1,
#  'Catherine Chapman': 1,
#  'Lawrence T. Lam': 1,
#  'Safiétou Mbaye': 1,
#  'Dongo Rémi Kouabenan': 1,
#  'M. Bevilacqua': 1,
#  'F.E. Ciarapica': 1,
#  'G. Giacchetta': 1,
#  'Vera L.G. Blank': 1,
#  'Lucie Laflamme': 1,
#  'Finn Diderichsen': 1,
#  'Stéphanie Bordel': 1,
#  'Alain Somat': 1,
#  'Hervé Barbeau': 1,
#  'Françoise Anceaux': 1,
#  'Catherine Greffeuille': 1,
#  'Gaëlle Menguy': 1,
#  'Marie-Pierre Pacaux': 1,
#  'Peggy Subirats': 1,
#  'Florence Terrade': 1,
#  'Marie-Line Gallenne': 1,
#  'Patrick Stahl': 1,
#  'Greg A. Jamieson': 1,
#  'Teemu Reiman': 1,
#  'Carl Rollenhagen': 1,
#  'Lauren A. Murphy': 1,
#  'Michelle M. Robertson': 1,
#  'Pascale Carayon': 1,
#  'Xiangling Zhuang': 1,
#  'F. Abdat': 1,
#  'S. Leclercq': 1,
#  'X. Cuny': 1,
#  'C. Tissot': 1,
#  'Jessica M. Patterson': 1,
#  'Scott A. Shappell': 1,
#  'Helen R. Marucci-Wellman': 1,
#  'Helen L. Corns': 1,
#  'Mark R. Lehto': 1,
#  'Peter M. Smith': 1,
#  'Ron Saunders': 1,
#  'Marni Lifshen': 1,
#  'Ollie Black': 1,
#  'Morgan Lay': 1,
#  'F. Curtis Breslin': 1,
#  'Anthony D. LaMontagne': 1,
#  'Emile Tompa': 1,
#  'Jonny Kuo': 1,
#  'Sjaan Koppel': 1,
#  'Judith L. Charlton': 1,
#  'Christina M. Rudin-Brown': 1,
#  'Nils Petter Gregersen': 1,
#  'Per Bjurulf': 1,
#  'Patrick J Ward': 1,
#  'Jean Jones': 1,
#  'Abhishek Das': 1,
#  'Drew M. Morris': 1,
#  'June J. Pilcher': 1,
#  'Fred S. {Switzer III}': 1,
#  'Mohammed Elhenawy': 1,
#  'Hesham A. Rakha': 1,
#  'Ihab El-Shawarby': 1,
#  'Seraphin C. Abou': 1,
#  'Kirsten McKenzie': 1,
#  'Deborah Anne Scott': 1,
#  'Margaret Ann Campbell': 1,
#  'Roderick John McClure': 1,
#  'T. Melman': 1,
#  'J.C.F. {de Winter}': 1,
#  'D.A. Abbink': 1,
#  'Lei Lin': 1,
#  'Qian Wang': 1,
#  'Adel W. Sadek': 1,
#  'Mohsen Naderpour': 1,
#  'Jie Lu': 1,
#  'Guangquan Zhang': 1,
#  'Hossein Rouzikhah': 1,
#  'Samuel Aupetit': 1,
#  'Jacques Riff': 1,
#  'Olivier Buttelli': 1,
#  'Stéphane Espié': 1,
#  'Benoît Depaire': 1,
#  'Geert Wets': 1,
#  'Koen Vanhoof': 1,
#  'Jinfu Yang': 1,
#  'John C. Milton': 1,
#  'Adélamar “Dely” Alcántara': 1,
#  'Noor Elmitiny': 1,
#  'Chris Russo': 1,
#  'Dina Nashar': 1,
#  'Hesham Rakha': 1,
#  'M. Lesch': 1,
#  'L. Simmons': 1,
#  'Lesley A. Ross': 1,
#  'Erica L. Schmidt': 1,
#  'Karlene Ball': 1,
#  'Yi-Shih Chung': 1,
#  'Erel Avineri': 1,
#  'Yusak O. Susilo': 1,
#  'Darren Bhattachary': 1,
#  'Huanjia Yang': 1,
#  'David A.S. Chew': 1,
#  'Weiwei Wu': 1,
#  'Zhipeng Zhou': 1,
#  'Qiming Li': 1,
#  'Guy H. Walker': 1,
#  'Paul M. Salmon': 1,
#  'Rami Harb': 1,
#  'Xiaogang Su': 1,
#  'Tova Rosenbloom': 1,
#  'Yuval Wolf': 1,
#  'Juneyoung Park': 1,
#  'Christopher J.D. Patten': 1,
#  'Albert Kircher': 1,
#  'Joakim Östlund': 1,
#  'Lena Nilsson': 1,
#  'Andrea Kiesel': 1,
#  'Zhen Qian': 1,
#  'Rafiqul A. Tarefder': 1,
#  'Zong Tian': 1,
#  'K.L Young': 1,
#  'S. Koppel': 1,
#  'J.L Charlton': 1,
#  'Randa Oqab Mujalli': 1,
#  'Griselda López': 1,
#  'Laura Garach': 1,
#  'Massimo Aria': 1,
#  'Antonio D’Ambrosio': 1,
#  'Shuaiyi Sun': 1,
#  'Shouen Fang': 1,
#  'Koji Suto': 1,
#  'Akimasa Fujiwara': 1,
#  'William Young': 1,
#  'Amir Sobhani': 1,
#  'Majid Sarvi': 1,
#  'Andreas Sonnleitner': 1,
#  'Matthias Sebastian Treder': 1,
#  'Michael Simon': 1,
#  'Sven Willmann': 1,
#  'Arne Ewald': 1,
#  'Axel Buchner': 1,
#  'Michael Schrauf': 1,
#  'A.J. Filtness': 1,
#  'C.M. Rudin-Brown': 1,
#  'C.M. Mulvihill': 1,
#  'M.G. Lenné': 1,
#  'Warren A. Harrison': 1,
#  'Ron Christie': 1,
#  'Katie J. Parnell': 1,
#  'Katherine L. Plant': 1,
#  'S.J. Bertke': 1,
#  'A.R. Meyers': 1,
#  'S.J. Wurzelbacher': 1,
#  'A. Measure': 1,
#  'M.P. Lampl': 1,
#  'D. Robins': 1,
#  'Helen M Wellman': 1,
#  'Mark R Lehto': 1,
#  'Gary S Sorock': 1,
#  'Gordon S Smith': 1,
#  'Ivan W.H. Fung': 1,
#  'Tommy Y. Lo': 1,
#  'Karen C.F. Tung': 1,
#  'Jacob B. Putnam': 1,
#  'Jeffrey T. Somers': 1,
#  'Jessica A. Wells': 1,
#  'Chris E. Perry': 1,
#  'Costin D. Untaroiu': 1,
#  'Yang Zheng': 1,
#  'Xiaofei Li': 1,
#  'Chenfei Yu': 1,
#  'Kenji Kodaka': 1,
#  'Keqiang Li': 1,
#  'Liz {de Rome}': 1,
#  'Rebecca Ivers': 1,
#  'Narelle Haworth': 1,
#  'Stephane Heritier': 1,
#  'Wei Du': 1,
#  'Michael Fitzharris': 1,
#  'Xiugang Li': 1,
#  'Yuanchang Xie': 1,
#  'Turki Alolah': 1,
#  'Rodney A. Stewart': 1,
#  'Kriengsak Panuwatwanich': 1,
#  'Sherif Mohamed': 1,
#  'Ann Williamson': 1,
#  'David A. Lombardi': 1,
#  'Simon Folkard': 1,
#  'Jane Stutts': 1,
#  'Theodore K. Courtney': 1,
#  'Jennie L. Connor': 1,
#  'Guozhen Zhao': 1,
#  'W.B. Verwey': 1,
#  'Jennifer A. Taylor': 1,
#  'Alicia V. Lacovara': 1,
#  'Gordon S. Smith': 1,
#  'Ravi Pandian': 1,
#  'Ho-Chan Kwak': 1,
#  'Seungyoung Kho': 1,
#  'Wei Chen': 1,
#  'Krista K. Wheeler': 1,
#  'Simon Lin': 1,
#  'Yungui Huang': 1,
#  'Huiyun Xiang': 1,
#  'Timo Lajunen': 1,
#  'Dianne Parker': 1,
#  'Michael A. Rupp': 1,
#  'Marc D. Gentzler': 1,
#  'Janan A. Smither': 1,
#  'Peter T. Savolainen': 1,
#  'Ni Dong': 1,
#  'Liang Zheng': 1,
#  'A.R. Cownie': 1,
#  'Bruce P. Hunn': 1,
#  'Thomas {A. Dingus}': 1,
#  'Baruch Fischhoff': 1,
#  'Lita Furby': 1,
#  'Robin Gregory': 1,
#  'Peter F. Lourens': 1,
#  'D.M. Pestonjee': 1,
#  'Ali Mekky': 1,
#  'Ferguson {John C.}': 1,
#  'McNally {Michael S.}': 1,
#  'Booth {Richard F.}': 1,
#  'Stephen J. Guastello': 1,
#  'Simon Hakim': 1,
#  'Daniel Shefer': 1,
#  'A.S. Hakkert': 1,
#  'Irit Hocherman': 1,
#  'J.T. Saari': 1,
#  'J. Lahtela': 1,
#  'Paul L. Zador': 1,
#  'Karl U. Smith': 1,
#  'Richard Kaplan': 1,
#  'Fred L. Mannering': 1,
#  'Gerald J.S. Wilde': 1,
#  'Christopher J. Colbourn': 1,
#  'Herbert Moskowitz': 1,
#  'Patrica Waller': 1,
#  'Gordan H. Robinson': 1,
#  'Roger L. Brown': 1,
#  'James Hedlund': 1,
#  'Robert Arnold': 1,
#  'Ezio Cerrelli': 1,
#  'Susan Partyka': 1,
#  'Paul Hoxie': 1,
#  'David Skinner': 1,
#  'Dinesh Mohan': 1,
#  'Urban Kjellén': 1,
#  'Toivo Niskanen': 1,
#  'Anthony N. Kontaratos': 1,
#  'S.E. Asogwa': 1}

# %% [markdown]
# ## Who are these Authors?

# %% [markdown]
# ### Mohamed Abdel-Aty
# - U of Central Florida
# - Editor in Chief Emeritus of the journal
# - PhD from Davis
#
# ### Zhibin Li
# - Southeast University, Nanjing
#
# ### Junhua Wang
# - Tongji U, Shanghai
#
# ### Rongjie Yu
# - Coauthor with Mohamed Abdel-Aty
# - Tongji U, Shanghai
#
# ### Pan Liu
# - Southeast University, Nanjing
# - Coauthors:
#     - Jie Bao (2)
#     - Satish V. Ukkusuri
#     - Xiao Qin
#     - Huaguo Zhou
#     - Yanyong Guo
#     - Zhibin Li (2)
#     - Yao Wu
#     - Wei Wang (2)
#     - Chengcheng Xu (2)
#
# ### Asad J. Khattak
# - U of Tennessee

# %% [markdown]
# # Institutions
# ## Sort Institutions by Frequency

# %%
x = 'institution'
P[x] = P[x].fillna('None')
A = [ x.split(' and ') for x in P[x].tolist() ]
B = [item for sublist in A for item in sublist]
C = {x:B.count(x) for x in B}
D = dict(sorted(C.items(), key=lambda item: item[1], reverse=True))
D
# Out:
# {'None': 318,
#  'Tsinghua U': 2,
#  'Louisiana State U': 2,
#  'North Dakota State U': 1,
#  'Southwest Jiaotong U': 1,
#  'Tongji U, Shanghai': 1,
#  'U of Central Florida': 1,
#  'Nanyang Technological U': 1,
#  'Northwestern U': 1,
#  'Shahid Bahonar U': 1,
#  'Southeast U, Nanjing': 1,
#  'Queensland U of Technology': 1,
#  'U of Natural Resources': 1,
#  'Life Sciences, Vienna': 1,
#  'Texas A\\&M U': 1}

# %% [markdown]
# # Interesting Articles

# %%
P['annotation'] = P['annotation'].fillna('None')
Interesting = P[P['annotation'].str.contains('Interesting', case=False)]
Interesting
# Out:
#                                             annotation  \
# 12   Interesting.  Numerical database of simulation...
# 71                                         Interesting
# 142  Random Forest for feature generation.  Only 72...
# 188                   Interesting.  Thorough analysis.
#
#                                               abstract  \
# 12   Accurate real-time prediction of occupant inju...
# 71   Highway work zones are most vulnerable roadway...
# 142  This study designs and evaluates a contextual ...
# 188  In the United States, there are approximately ...
#
#                                               keywords  \
# 12   Motor vehicle crashes, Occupant protection, In...
# 71   Traffic collision/accident severity, Deep lear...
# 142  Drowsiness, Detection, Dynamic Bayesian Networ...
# 188  Highway-Rail Grade Crossing Consolidation, Clo...
#
#                                                 author  \
# 12   Qingfan Wang and Shun Gan and Wentao Chen and ...
# 71                  Md Adilur Rahim and Hany M. Hassan
# 142  Anthony D. McDonald and John D. Lee and Chris ...
# 188  Samira Soleimani and Saleh R. Mousa and Julius...
#
#                                                    url  \
# 12   https://www.sciencedirect.com/science/article/...
# 71   https://www.sciencedirect.com/science/article/...
# 142  https://www.sciencedirect.com/science/article/...
# 188  https://www.sciencedirect.com/science/article/...
#
#                                            doi       issn  year   pages  \
# 12   https://doi.org/10.1016/j.aap.2021.106149  0001-4575  2021  106149
# 71   https://doi.org/10.1016/j.aap.2021.106090  0001-4575  2021  106090
# 142  https://doi.org/10.1016/j.aap.2018.01.005  0001-4575  2018   25-37
# 188  https://doi.org/10.1016/j.aap.2019.04.002  0001-4575  2019   65-77
#
#     volume  ... Hyperparameters Spearman Aggregated Gain Time Dependencies  \
# 12     156  ...           False    False           False             False
# 71     154  ...           False    False           False             False
# 142    113  ...           False    False           False              True
# 188    128  ...           False    False            True             False
#
#     Temporal Kinematic Visualization  \
# 12     False      True          True
# 71     False     False         False
# 142     True     False         False
# 188    False     False         False
#
#     Second Highway Research Program (Data Set)  F1 Loss Function  \
# 12                                       False             False
# 71                                       False              True
# 142                                      False             False
# 188                                      False             False
#
#      Connected Vehicles
# 12                False
# 71                False
# 142               False
# 188               False
#
# [4 rows x 61 columns]

# %% [markdown]
# # Not Machine Learning

# %%
A = P[P['annotation'].str.contains('Not ML', case=False)]
A
# Out:
#     annotation                                           abstract  \
# 34      Not ML  Given the severe traffic safety issue, tremend...
# 81      Not ML  The autonomous vehicle is regarded as a promis...
# 101     Not ML  As part of the emerging world of intelligent t...
# 116     Not ML  Traditional statistical crash prediction model...
# 130     Not ML  Mobile phone distracted driving is a major ris...
#
#                                               keywords  \
# 34   Driving capability assessment, Longitudinal dr...
# 81   Autonomous vehicles, Driving strategy, Risk ap...
# 101  Driver behavior, Vehicle trajectories, Connect...
# 116  Bivariate extreme value theory, Video-based ve...
# 130  Cell phone, Ergonomics, Human-machine interact...
#
#                                                 author  \
# 34   Rongjie Yu and Xiaojie Long and Mohammed Quddu...
# 81   Can Zhao and Li Li and Xin Pei and Zhiheng Li ...
# 101               Zihan Hong and Ying Chen and Yang Wu
# 116           Chen Wang and Chengcheng Xu and Yulu Dai
# 130  Oscar Oviedo-Trespalacios and Verity Truelove ...
#
#                                                    url  \
# 34   https://www.sciencedirect.com/science/article/...
# 81   https://www.sciencedirect.com/science/article/...
# 101  https://www.sciencedirect.com/science/article/...
# 116  https://www.sciencedirect.com/science/article/...
# 130  https://www.sciencedirect.com/science/article/...
#
#                                            doi       issn  year    pages  \
# 34   https://doi.org/10.1016/j.aap.2020.105779  0001-4575  2020   105779
# 81   https://doi.org/10.1016/j.aap.2020.105937  0001-4575  2021   105937
# 101  https://doi.org/10.1016/j.aap.2020.105460  0001-4575  2020   105460
# 116  https://doi.org/10.1016/j.aap.2018.12.013  0001-4575  2019  365-373
# 130  https://doi.org/10.1016/j.aap.2019.105412  0001-4575  2020   105412
#
#     volume  ... Hyperparameters Spearman Aggregated Gain Time Dependencies  \
# 34     147  ...           False    False           False             False
# 81     150  ...           False    False           False             False
# 101    139  ...           False    False           False             False
# 116    123  ...           False    False           False             False
# 130    137  ...           False    False           False             False
#
#     Temporal Kinematic Visualization  \
# 34     False     False         False
# 81     False     False         False
# 101    False     False         False
# 116    False     False         False
# 130    False     False         False
#
#     Second Highway Research Program (Data Set)  F1 Loss Function  \
# 34                                       False             False
# 81                                       False             False
# 101                                      False             False
# 116                                      False             False
# 130                                      False             False
#
#      Connected Vehicles
# 34                False
# 81                False
# 101                True
# 116               False
# 130               False
#
# [5 rows x 61 columns]
